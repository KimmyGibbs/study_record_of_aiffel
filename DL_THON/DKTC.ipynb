# %% [markdown]
# # **2. DKTC (Dataset of Korean Threatening Conversations)**

# %% [markdown]
# ## **2-1. DKTC (Dataset of Korean Threatening Conversations)**

# %% [markdown]
# 안녕하세요, DLThon을 시작해볼까요!.😁<br>
# 여러분이 지금까지 교육 과정 중 배운 내용을 토대로, 아래의 데이터셋을 활용하여 프로젝트를 구성해주세요.

# %% [markdown]
# <br><br>

# %% [markdown]
# #### **데이터셋 정보**
#
# ---
#
# 본 데이터셋은 tunib에서 제공하는 데이터셋으로, 멀티턴 대화 형식의 데이터로 구성되어 있습니다.

# %% [markdown]
# **train.csv**
#
# ```shell
# 1. idx = 인덱스
# 2. class = 협박 대화, 갈취 대화, 직장 내 괴롭힘 대화, 기타 괴롭힘 대화
# 3. conversation = \n으로 구분된 멀티턴 텍스트 대화
# ```

# %% [markdown]
# **test.json**
#
# ```shell
# 1. t_### = 인덱스
# 2. text = 대화
# ```

# %% [markdown]
# **submission.csv**
#
# ```shell
# 1. file_name = 인덱스
# 2. class = 예측값
# ```

# %% [markdown]
# <br>

# %% [markdown]
# #### **데이터셋**
#
# ```shell
# $ mkdir -p ~/aiffel/dktc
# $ ln -s ~/data/ ~/aiffel/dktc
# ```

# %%
import os
import pandas as pd
import tensorflow as tf
from transformers import BertTokenizer, TFBertForSequenceClassification
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import plot_model
import json
  
train_data_path ="/aiffel/aiffel/dktc/data/train.csv"
train_data = pd.read_csv(train_data_path)
# train_data.head()

for val in train_data['class']:
    if '직장' in val:
        print(val)
        break

# labels = []

# for val in train_data['class']:    
#     if '갈취' in val:
## 갈취 대화
#         labels.append(1)
#     if '기타' in val:
## 기타 괴롭힘 대화
#         labels.append(3)
#     if '직장' in val:
#         labels.append(2)
#     if '협박' in val:
## 협박 대화
#         labels.append(0)

# len(labels) ## 3950

# 데이터셋 분할
# train_sentences, val_sentences, train_labels, val_labels = train_test_split(
#     sentences, labels, test_size=0.2, random_state=42
# )

# BERT 토크나이저와 모델 준비
# tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")
# model = TFBertForSequenceClassification.from_pretrained("bert-base-multilingual-cased", num_labels=4)

# 데이터셋을 BERT 입력 형식으로 변환
# train_encodings = tokenizer(train_sentences, truncation=True, padding=True, max_length=128)
# val_encodings = tokenizer(val_sentences, truncation=True, padding=True, max_length=128)

# TensorFlow 데이터셋 생성
# train_dataset = tf.data.Dataset.from_tensor_slices((
#     dict(train_encodings),
#     train_labels
# )).shuffle(100).batch(16)

# val_dataset = tf.data.Dataset.from_tensor_slices((
#     dict(val_encodings),
#     val_labels
# )).batch(16)

# 모델 컴파일 및 훈련
# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#               metrics=['accuracy'])

# model.fit(train_dataset, validation_data=val_dataset, epochs=3)

# 모델 구조 시각화
# plot_model(model, show_shapes=True, show_layer_names=True)

# 모델 평가
# evaluation = model.evaluate(val_dataset)
# print("평가 결과:", evaluation)

# %% [markdown]
# <br>

# %% [markdown]
# #### **과제**
#
# ---

# %% [markdown]
# 1. DKTC 훈련 데이터를 이용해 <br>**협박**, **갈취**, **직장 내 괴롭힘**, **기타 괴롭힘** 4가지 대화 유형 Class를 분류하는 딥러닝 모델을 만듭니다.
# 2. DKTC 테스트 데이터를 활용해 분류 성능을 평가합니다.
# 3. 분류 성능의 경우 [리더보드](https://m.site.naver.com/1cB6a)를 통해서 확인할 수 있습니다.

# %% [markdown]
# **리더보드 사이트 : https://m.site.naver.com/1cB6a**
#
# (참고: 2023.10.02 기준 리더보드 페이지 blocked)

# %% [markdown]
# <br>

# %% [markdown]
# #### **원본 과제 참고 링크**
#
# ---
#
# [Tunib GitHub](https://github.com/tunib-ai/DKTC)

# %% [markdown]
# <br>

# %% [markdown]
# #### **규칙**
#
# 1. **아래 프로젝트 평가 항목**을 참고하여 프로젝트를 수행해주세요.
#
# 2. **프로젝트 최종 결과물** 이 업로드된 깃헙 링크를 프로젝트 제출 기한 내 2-3 프로젝트 제출 스텝에 제출해주세요.<br> **(재현가능한 코드가 담긴 주피터 노트북 파일 & 발표자료 PPT)**
#
# 3. 외부 데이터 활용은 허용하되, 제공된 데이터를 활용한 기록이 필수적으로 포함되어야 합니다.
#
# 4. 부정 제출 행위를 금지하고 있으며, 부정 제출 이력이 있는 경우 평가가 제한됩니다.

# %% [markdown]
# #### **프로젝트 평가 항목**
#
# ---

# %% [markdown]
# 1. 데이터 EDA와 데이터 전처리가 적절하게 이뤄졌는가?
#
# 2. Task에 알맞게 적절한 모델을 찾아보고 선정했는가?
#
# 3. 성능향상을 위해 논리적으로 접근했는가?
#
# 4. 결과 도출을 위해 여러가지 시도를 진행했는가?
#
# 5. 도출된 결론에 충분한 설득력이 있는가?
#
# 6. 적절한 metric을 설정하고 그 사용 근거 및 결과를 분석하였는가?
#
# 7. 발표가 매끄럽게 진행되었고 발표시간을 준수하였는지?

# %% [markdown]
# ## **2-2. DLThon**

# %% [markdown]
# ### **DLthon 시작!**
#
# ---
#
# 이 노드는 여러분들이 편하게 DLthon 프로젝트를 할 수 있도록 환경을 세팅했습니다. TensorFlow를 기본적으로, 저희가 각 노드에서 사용했던 라이브러리들이 탑재되어 있습니다. 추가로 PyTorch도 세팅되어 있습니다.

# %% [markdown]
# 환경을 확인하실 수 있도록 간단한 코드를 첨부했습니다.

# %% [markdown]
# 여러분들이 프로젝트를 진행할 때, 추가적인 라이브러리 버전 세팅이 필요할 수 있습니다. 이 경우, 필요한 환경의 검토가 완료되면 세션이 새롭게 시작될 때 환경 설정에 필요한 코드를 미리 준비해 두시면 좋습니다.

# %% [markdown]
# 스토리지에서 `/aiffel` 하위 디렉토리는 아시다시피 리셋 되지 않습니다. 모델 웨이트 등의 자료 및 코드 저장에 참고하시면 좋겠습니다.

# %% [markdown]
# 화이팅 넘치게 DLthon을 달려볼까요?? 🏃‍♂️🏃‍♀️<br>
# 힘차게 가보자구우!! 💪💪

# %%
# 이 코드를 실행해보시면 설치된 라이브러리 버전을 확인해보실 수 있습니다.
# !pip list

# %% [markdown]
# <details>
# <summary>pip list in the node of DLthon</summary>
#
# ```
# Package                       Version
# ----------------------------- ------------------
# absl-py                       0.12.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# albumentations                1.1.0
# antlr4-python3-runtime        4.8
# anyio                         3.4.0
# appdirs                       1.4.4
# argon2-cffi                   21.1.0
# astunparse                    1.6.3
# async-generator               1.10
# async-timeout                 4.0.1
# attrs                         21.2.0
# audioread                     2.1.9
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.6.0
# black                         21.12b0
# bleach                        4.1.0
# branca                        0.4.2
# brotlipy                      0.7.0
# cachetools                    4.2.4
# certifi                       2021.10.8
# cffi                          1.15.0
# chardet                       3.0.4
# charset-normalizer            2.0.8
# clang                         5.0
# click                         8.0.3
# click-plugins                 1.1.1
# cligj                         0.7.2
# cloudpickle                   2.0.0
# cmake                         3.21.3
# colorama                      0.4.4
# conda                         4.11.0
# conda-build                   3.21.7
# conda-package-handling        1.7.3
# cryptography                  36.0.0
# cssselect                     1.1.0
# customized-konlpy             0.0.64
# cycler                        0.11.0
# Cython                        0.29.24
# dataclasses                   0.6
# datasets                      1.14.0
# debugpy                       1.5.1
# decorator                     4.4.2
# defusedxml                    0.7.1
# delayed                       0.11.0b1
# Deprecated                    1.2.13
# dill                          0.3.4
# dlib                          19.22.1
# docutils                      0.18.1
# editdistance                  0.6.0
# efficientnet                  1.0.0
# efficientnet-pytorch          0.7.1
# entrypoints                   0.3
# essential-generators          1.0
# face-recognition              1.3.0
# face-recognition-models       0.3.0
# feedfinder2                   0.0.4
# feedparser                    6.0.8
# filelock                      3.4.0
# Fiona                         1.8.20
# Flask                         2.0.2
# flask-ngrok                   0.0.25
# flatbuffers                   1.12
# folium                        0.12.1
# fonttools                     4.28.3
# frozenlist                    1.2.0
# fsspec                        2021.11.1
# future                        0.18.2
# fvcore                        0.1.5.post20211023
# gast                          0.4.0
# gensim                        4.1.2
# geopandas                     0.10.1
# glob2                         0.7
# google-api-core               2.2.2
# google-api-python-client      2.26.1
# google-auth                   2.3.3
# google-auth-httplib2          0.1.0
# google-auth-oauthlib          0.4.6
# google-cloud-vision           2.5.0
# google-pasta                  0.2.0
# googleapis-common-protos      1.53.0
# googletrans                   3.0.0
# grpcio                        1.42.0
# grpcio-status                 1.42.0
# h11                           0.9.0
# h2                            3.2.0
# h3                            3.7.3
# h5py                          3.1.0
# hiredis                       2.0.0
# hpack                         3.0.0
# hstspreload                   2021.12.1
# httpcore                      0.9.1
# httplib2                      0.20.2
# httpx                         0.13.3
# huggingface-hub               0.0.19
# hydra-core                    1.1.1
# hyperframe                    5.2.0
# idna                          2.10
# imageio                       2.9.0
# imageio-ffmpeg                0.4.5
# imantics                      0.1.12
# imbalanced-learn              0.8.1
# imgaug                        0.4.0
# implicit                      0.4.8
# importlib-metadata            4.8.2
# importlib-resources           5.4.0
# iopath                        0.1.9
# ipykernel                     6.6.0
# ipython                       7.28.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# itsdangerous                  2.0.1
# jedi                          0.18.1
# jieba3k                       0.35.1
# Jinja2                        3.0.3
# joblib                        1.1.0
# JPype1                        1.3.0
# jsonpickle                    2.0.0
# jsonschema                    4.2.1
# jupyter-client                7.1.0
# jupyter-core                  4.9.1
# jupyter-desktop-server        0.1.3
# jupyter-server                1.13.1
# jupyter-server-proxy          3.2.0
# jupyterlab-pygments           0.1.2
# jupyterlab-widgets            1.0.2
# keras                         2.6.0
# Keras-Applications            1.0.8
# keras-ocr                     0.8.8
# Keras-Preprocessing           1.1.2
# kiwisolver                    1.3.2
# konlpy                        0.5.2
# labelme2coco                  0.1.2
# libarchive-c                  3.2
# librosa                       0.8.1
# lightgbm                      3.3.0
# llvmlite                      0.36.0
# lmdb                          1.2.1
# loguru                        0.5.3
# lxml                          4.6.3
# Markdown                      3.3.6
# MarkupSafe                    2.0.1
# matplotlib                    3.4.3
# matplotlib-inline             0.1.3
# matplotlib-venn               0.11.6
# mecab-python                  0.996-ko-0.9.2
# mido                          1.2.10
# missingno                     0.5.0
# mistune                       0.8.4
# moviepy                       1.0.3
# msgpack                       1.0.3
# multidict                     5.2.0
# multiprocess                  0.70.12.2
# munch                         2.5.0
# mypy-extensions               0.4.3
# nbclient                      0.5.9
# nbconvert                     6.3.0
# nbformat                      5.1.3
# nest-asyncio                  1.5.4
# networkx                      2.6.3
# newspaper3k                   0.2.8
# nltk                          3.6.5
# notebook                      6.1.6
# numba                         0.53.1
# numpy                         1.21.4
# oauthlib                      3.1.1
# omegaconf                     2.1.1
# opencv-contrib-python         4.5.3.56
# opencv-python                 4.5.3.56
# opencv-python-headless        4.5.4.60
# opt-einsum                    3.3.0
# outcome                       1.1.0
# packaging                     21.3
# pandas                        1.3.3
# pandocfilters                 1.5.0
# parso                         0.8.3
# pathspec                      0.9.0
# patsy                         0.5.2
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        8.3.2
# pip                           21.3.1
# pixellib                      0.7.1
# pkginfo                       1.8.1
# platformdirs                  2.4.0
# pmdarima                      1.8.3
# pooch                         1.5.2
# portalocker                   2.3.2
# proglog                       0.1.9
# prometheus-client             0.12.0
# promise                       2.3
# prompt-toolkit                3.0.22
# proto-plus                    1.19.8
# protobuf                      3.19.1
# psutil                        5.8.0
# ptyprocess                    0.7.0
# py4j                          0.10.9
# pyarrow                       6.0.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pyclipper                     1.3.0.post2
# pycosat                       0.6.3
# pycparser                     2.21
# pydot                         1.4.2
# pydotplus                     2.0.2
# Pygments                      2.10.0
# pyOpenSSL                     21.0.0
# pyparsing                     3.0.6
# pyproj                        3.2.1
# PyQt5                         5.15.6
# PyQt5-Qt5                     5.15.2
# PyQt5-sip                     12.9.0
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pyspark                       3.1.2
# pytesseract                   0.3.8
# python-dateutil               2.8.2
# python-Levenshtein            0.12.2
# pytz                          2021.3
# pyvis                         0.1.9
# PyWavelets                    1.2.0
# PyYAML                        6.0
# pyzmq                         22.3.0
# qudida                        0.0.4
# ray                           1.7.0
# redis                         4.0.2
# regex                         2021.11.10
# requests                      2.26.0
# requests-file                 1.5.1
# requests-oauthlib             1.3.0
# resampy                       0.2.2
# rfc3986                       1.5.0
# rsa                           4.8
# ruamel-yaml-conda             0.15.80
# sacremoses                    0.0.46
# scikit-image                  0.18.3
# scikit-learn                  1.0
# scipy                         1.7.1
# seaborn                       0.11.2
# selenium                      4.0.0
# Send2Trash                    1.8.0
# sentencepiece                 0.1.96
# setuptools                    59.4.0
# sgmllib3k                     1.0.0
# Shapely                       1.7.1
# simpervisor                   0.4
# six                           1.16.0
# smart-open                    5.2.1
# sniffio                       1.2.0
# sortedcontainers              2.4.0
# SoundFile                     0.10.3.post1
# soupsieve                     2.3.1
# soynlp                        0.0.493
# statistics                    1.0.3.5
# statsmodels                   0.13.0
# summa                         1.2.0
# tabulate                      0.8.9
# tensorboard                   2.7.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.0
# tensorflow-addons             0.14.0
# tensorflow-datasets           4.4.0
# tensorflow-estimator          2.7.0
# tensorflow-gpu                2.6.0
# tensorflow-hub                0.12.0
# tensorflow-metadata           1.5.0
# termcolor                     1.1.0
# terminado                     0.12.1
# testpath                      0.5.0
# threadpoolctl                 3.0.0
# tifffile                      2021.11.2
# tinysegmenter                 0.3
# tldextract                    3.1.2
# tokenizers                    0.10.3
# tomli                         1.2.2
# torch                         1.9.1+cu111
# torchaudio                    0.9.1
# torchvision                   0.10.1+cu111
# tornado                       6.1
# tqdm                          4.62.3
# traitlets                     5.1.1
# transformers                  4.11.3
# trio                          0.19.0
# trio-websocket                0.9.2
# tweepy                        3.10.0
# typeguard                     2.13.2
# typing_extensions             4.0.1
# uritemplate                   4.1.1
# urllib3                       1.26.7
# validators                    0.18.2
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.2.3
# websockify                    0.10.0
# Werkzeug                      2.0.2
# wget                          3.2
# wheel                         0.37.0
# widgetsnbextension            3.5.2
# wordcloud                     1.8.1
# wrapt                         1.12.1
# wsproto                       1.0.0
# xgboost                       1.4.2
# xmljson                       0.2.1
# xxhash                        2.0.2
# yacs                          0.1.8
# yarl                          1.7.2
# zipp                          3.6.0
# ```
# </details>

# %%
# GPU로 Tesla T4가 준비돼있습니다.
# !nvidia-smi

# %% [markdown]
# <details>
# <summary>GPU status in the node</summary>
#
# ```shell
# Sun Oct  1 15:14:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# ```
# </details>

# %% [markdown]
# ## **2-3. 프로젝트 제출**

# %% [markdown]
# ##### 루브릭
#
# 아래의 기준을 바탕으로 프로젝트를 평가합니다.

# %% [markdown]
# |**평가문항**|**상세기준**|
# |--|--|
# |1. 데이터 전처리 과정이 잘 이루어졌는가?|데이터 정제 및 토큰화를 잘 수행하였다. 모델 학습에 충분한 데이터를 추가 수집 및 augmentation 하였다.|
# |2. 적절한 모델 및 평가지표를 선정했는가?|한국어 문장 분류에 적절한 모델과, 해당 데이터셋 분류에 적합한 metric을 선택하고 선택 근거 및 결과를 잘 분석하였다.|
# |3. 모델의 분류 성능을 얼마나 달성했는가?|선정한 metric에 따라 성능 개선 과정을 분석하고 목표한 수치 이상의 성능을 달성해냈다.|
